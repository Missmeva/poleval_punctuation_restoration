# %% [markdown]
# # PolEval - Punctuation restoration from read text
#
# Głównym celem projektu jest stworzenie narzędzia, który będzie przywracał znaki interpunkcyjne - | . | , | ? | ! | etc., zgodnie z opisem zadania na [oficjalnej stronie konkursu PolEval](https://beta.poleval.pl/challenge/punctuation-restoration).

# %% [markdown]
# ### Wczytanie bibliotek###

# %%
import pandas as pd
import numpy as np

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print("GPUs Available: ", (tf.test.is_gpu_available()))
device_lib.list_local_devices()
# Out:
# WARNING:tensorflow:From <ipython-input-2-f41b6b1b96a2>:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPUs Available:  True
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9140373945506772626
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5654970368
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9438706159457170788
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ### Zbiór danych###

# %%
data=pd.read_csv('data/train/in.tsv', names = ['FileId', 'ASROutput'], sep='\t')
data.head()
# Out:
#            FileId                                          ASROutput
# 0  wikinews228460  w wywiadzie dla " polski " jarosław kaczyński ...
# 1  wikinews183471  dowody prokuratury przedstawiające że janusz k...
# 2  wikinews188040  w czasie długiego weekendu 1 3 maja 2009 w jad...
# 3  wikinews178804  drugie zwycięstwo w tegorocznym giro d'italia ...
# 4  wikinews231649  takiego mrozu nie było w polsce od dawna słupk...

# %%
data=pd.read_csv('data/train/expected.tsv', names = ['ASROutput'], sep='\t')
pd.set_option('max_colwidth', 200)
data.head()
# Out:
#                                                                                                                                                                                                  ASROutput
# 0  w wywiadzie dla " polski " jarosław kaczyński podkreślił, że informacje dotyczące radosława sikorskiego zagrażają interesowi państwa. " to naprawdę wszystko, co mogę na ten temat powiedzieć "- odp...
# 1  dowody prokuratury przedstawiające, że janusz kaczmarek, były szef mswia, kłamał, wypierając się spotkania z ryszardem krauze 5 lipca- nie osłabiły determinacji opozycji. teraz opozycja żąda przes...
# 2  w czasie długiego weekendu, 1- 3 maja 2009 w jadwisinie nad jeziorem zegrzyńskim stowarzyszenie wikimedia polska organizuje konferencję poświęconą zarówno wikimediom, m. in. wikipedii, jak i rucho...
# 3  drugie zwycięstwo w tegorocznym giro d'italia odniósł danilo di luca z grupy liquigas, zmieniając tym samym paolo bettiniego na pozycji lidera. wyścig przebiegał dzisiaj 223- kilometrową trasą z c...
# 4  takiego mrozu nie było w polsce od dawna. słupki rtęci w znaczącej części polski spadły nie tylko poniżej 10 stopni na minusie, ale nawet poniżej 20 bądź 30 tak zimno jest od czwartku m. in. w suw...

# %%
PUNCTUATION = ['"-', ',', '.', ':', ';', '?', '!', '"', '%', '&', '(', ')', "'"]

# %%
import nltk
from nltk.tokenize import wordpunct_tokenize

DATA_SHAPE = data.shape[0]
data["ASROutput"] = data["ASROutput"].apply(lambda x: wordpunct_tokenize(x))

# %%
data["ASROutput"].head()
# Out:
# 0    [w, wywiadzie, dla, ", polski, ", jarosław, kaczyński, podkreślił, ,, że, informacje, dotyczące, radosława, sikorskiego, zagrażają, interesowi, państwa, ., ", to, naprawdę, wszystko, ,, co, mogę, ...
# 1    [dowody, prokuratury, przedstawiające, ,, że, janusz, kaczmarek, ,, były, szef, mswia, ,, kłamał, ,, wypierając, się, spotkania, z, ryszardem, krauze, 5, lipca, -, nie, osłabiły, determinacji, opo...
# 2    [w, czasie, długiego, weekendu, ,, 1, -, 3, maja, 2009, w, jadwisinie, nad, jeziorem, zegrzyńskim, stowarzyszenie, wikimedia, polska, organizuje, konferencję, poświęconą, zarówno, wikimediom, ,, m...
# 3    [drugie, zwycięstwo, w, tegorocznym, giro, d, ', italia, odniósł, danilo, di, luca, z, grupy, liquigas, ,, zmieniając, tym, samym, paolo, bettiniego, na, pozycji, lidera, ., wyścig, przebiegał, dz...
# 4    [takiego, mrozu, nie, było, w, polsce, od, dawna, ., słupki, rtęci, w, znaczącej, części, polski, spadły, nie, tylko, poniżej, 10, stopni, na, minusie, ,, ale, nawet, poniżej, 20, bądź, 30, tak, z...
# Name: ASROutput, dtype: object

# %%
train_set = data["ASROutput"]
train_set = [item for sublist in train_set for item in sublist]
train_set = np.array(train_set)
train_set.shape
# Out:
# (189129,)

# %%
TOKEN_COUNT = train_set.shape[0]
drop_indices = [idx for idx in range(TOKEN_COUNT) if train_set[idx] in PUNCTUATION ]
labels = [train_set[idx+1] if idx+1 in drop_indices else 'NO' for idx in range(TOKEN_COUNT)]
labels = np.array(labels)
X_ = np.delete(train_set, drop_indices)
labels = np.delete(labels, drop_indices)

assert (X_.shape[0] == len(labels))

# %%
# print example

vocab_punct = {'Token': X_.tolist(), 'Punctuation': labels}
df_dataset_view = pd.DataFrame(data=vocab_punct)
df_dataset_view[:20]
# Out:
#           Token Punctuation
# 0             w          NO
# 1     wywiadzie          NO
# 2           dla           "
# 3        polski           "
# 4      jarosław          NO
# 5     kaczyński          NO
# 6    podkreślił           ,
# 7            że          NO
# 8    informacje          NO
# 9     dotyczące          NO
# 10    radosława          NO
# 11  sikorskiego          NO
# 12    zagrażają          NO
# 13   interesowi          NO
# 14      państwa           .
# 15           to          NO
# 16     naprawdę          NO
# 17     wszystko           ,
# 18           co          NO
# 19         mogę          NO

# %% [markdown]
# ### Word2Vec###

# %%
import fasttext
import fasttext.util

ft = fasttext.load_model('cc.pl.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
WORD_2_VEC_SIZE = 300

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(labels)
y = le.transform(labels)

# %%
print(y[:15])
print(labels[:15])
# Out:
# [12 12  1  1 12 12  7 12 12 12 12 12 12 12  8]
# ['NO' 'NO' '"' '"' 'NO' 'NO' ',' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' 'NO' '.']

# %%
from collections import Counter
Counter(labels)
# Out:
# Counter({'NO': 140460,
#          '"': 1684,
#          ',': 9852,
#          '.': 10009,
#          '"-': 365,
#          ':': 905,
#          '?': 750,
#          "'": 140,
#          '%': 119,
#          '!': 116,
#          ';': 89,
#          '(': 8,
#          ')': 11})

# %%
y.shape
# Out:
# (164508,)

# %%
X = np.empty((X_.shape[0], WORD_2_VEC_SIZE), dtype = float)
for idx, token in np.ndenumerate(X_):
    X[idx] = ft.get_word_vector(token)

# %%
X.shape
# Out:
# (164508, 300)

# %%
X[:10]
# Out:
# array([[ 0.15531263, -0.04308021, -0.00168156, ...,  0.04180686,
#         -0.00038691, -0.10296766],
#        [ 0.04996644,  0.03045041, -0.03490978, ...,  0.01671311,
#          0.04654586, -0.02967763],
#        [-0.11573004,  0.0370084 ,  0.04243099, ...,  0.01563751,
#          0.10110958, -0.02245275],
#        ...,
#        [ 0.25485411,  0.13717936, -0.02394456, ..., -0.07372162,
#         -0.10366685,  0.01764201],
#        [-0.02322206,  0.00295874,  0.02591213, ...,  0.00349834,
#         -0.0202674 ,  0.04200821],
#        [-0.02845111,  0.00157207,  0.02760693, ...,  0.01035177,
#         -0.01641942,  0.02249819]])

# %% [markdown]
# ###Model

# %% [markdown]
# Set floating point precision to 16-*bit*

# %%
from tensorflow.keras import mixed_precision
import tensorflow.keras.backend as K
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
K.set_epsilon(1e-4)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3080 Laptop GPU, compute capability 8.6

# %%
from keras.models import Sequential
from keras.layers import Input, CuDNNLSTM, Dense, LSTM, Flatten, Dropout
import keras.backend as K

model = Sequential()
model.add(CuDNNLSTM(256, return_sequences=True, input_shape=(X.shape[1], 1)))
model.add(CuDNNLSTM(128, return_sequences=True))
model.add(Flatten())
model.add(Dropout(.2))
model.add(Dense(32,activation='relu'))
model.add(Dropout(.2))
model.add(Dense(len(le.classes_), activation='softmax'))

model.compile(loss=['sparse_categorical_crossentropy'], optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  cu_dnnlstm (CuDNNLSTM)      (None, 300, 256)          265216
#
#  cu_dnnlstm_1 (CuDNNLSTM)    (None, 300, 128)          197632
#
#  flatten (Flatten)           (None, 38400)             0
#
#  dropout (Dropout)           (None, 38400)             0
#
#  dense (Dense)               (None, 32)                1228832
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_1 (Dense)             (None, 13)                429
#
# =================================================================
# Total params: 1,692,109
# Trainable params: 1,692,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=10, batch_size=256, validation_split=0.2, verbose=2)
# Out:
# Epoch 1/10
# 515/515 - 31s - loss: 0.6054 - accuracy: 0.8540 - val_loss: 0.5366 - val_accuracy: 0.8582 - 31s/epoch - 60ms/step
# Epoch 2/10
# 515/515 - 27s - loss: 0.5540 - accuracy: 0.8575 - val_loss: 0.5205 - val_accuracy: 0.8600 - 27s/epoch - 52ms/step
# Epoch 3/10
# 515/515 - 27s - loss: 0.5366 - accuracy: 0.8585 - val_loss: 0.5179 - val_accuracy: 0.8603 - 27s/epoch - 52ms/step
# Epoch 4/10
# 515/515 - 27s - loss: 0.5272 - accuracy: 0.8590 - val_loss: 0.5055 - val_accuracy: 0.8605 - 27s/epoch - 52ms/step
# Epoch 5/10
# 515/515 - 27s - loss: 0.5222 - accuracy: 0.8592 - val_loss: 0.5109 - val_accuracy: 0.8606 - 27s/epoch - 52ms/step
# Epoch 6/10
# 515/515 - 27s - loss: 0.5167 - accuracy: 0.8595 - val_loss: 0.5021 - val_accuracy: 0.8607 - 27s/epoch - 52ms/step
# Epoch 7/10
# 515/515 - 27s - loss: 0.5112 - accuracy: 0.8593 - val_loss: 0.5017 - val_accuracy: 0.8606 - 27s/epoch - 52ms/step
# Epoch 8/10
# 515/515 - 27s - loss: 0.5074 - accuracy: 0.8594 - val_loss: 0.5000 - val_accuracy: 0.8606 - 27s/epoch - 52ms/step
# Epoch 9/10
# 515/515 - 27s - loss: 0.5048 - accuracy: 0.8595 - val_loss: 0.4995 - val_accuracy: 0.8606 - 27s/epoch - 52ms/step
# Epoch 10/10
# 515/515 - 27s - loss: 0.5013 - accuracy: 0.8597 - val_loss: 0.5002 - val_accuracy: 0.8606 - 27s/epoch - 52ms/step

# %%
from keras.models import Sequential
from keras.layers import Input, CuDNNLSTM, Dense, LSTM, Flatten, Bidirectional, Dropout
from sklearn.utils import class_weight

class_weights = {
    0: 1.,
    1: 0.8,
    2: 1.,
    3: 1.,
    4: 1.,
    5: 1.,
    6: 1.,
    7: 0.8,
    8: 0.8,
    9: 0.8,
    10: 1.,
    11: 1.,
    12: 0.1
}

early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=2)

model_bi = Sequential()
model_bi.add(Bidirectional(CuDNNLSTM(256, return_sequences=True), input_shape=(X.shape[1], 1)))
model_bi.add(Bidirectional(CuDNNLSTM(128, return_sequences=True)))
model_bi.add(Flatten())
model_bi.add(Dropout(.2))
model_bi.add(Dense(32,activation='relu'))
model_bi.add(Dropout(.2))
model_bi.add(Dense(len(le.classes_), activation='softmax'))

model_bi.compile(loss=['sparse_categorical_crossentropy'], optimizer='adam', metrics=['accuracy'])
model_bi.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 300, 512)         530432
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 300, 256)         657408
#  nal)
#
#  flatten_1 (Flatten)         (None, 76800)             0
#
#  dropout_2 (Dropout)         (None, 76800)             0
#
#  dense_2 (Dense)             (None, 32)                2457632
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 13)                429
#
# =================================================================
# Total params: 3,645,901
# Trainable params: 3,645,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_bi = model_bi.fit(X, y, epochs=50, batch_size=1024, validation_split=0.2, class_weight = class_weights, callbacks = [early_stopping_callback], verbose=2)
# Out:
# Epoch 1/50
# 129/129 - 77s - loss: 0.3047 - accuracy: 0.6483 - val_loss: 0.8879 - val_accuracy: 0.7162 - 77s/epoch - 598ms/step
# Epoch 2/50
# 129/129 - 32s - loss: 0.2769 - accuracy: 0.6785 - val_loss: 0.9491 - val_accuracy: 0.6484 - 32s/epoch - 245ms/step
# Epoch 3/50
# 129/129 - 32s - loss: 0.2679 - accuracy: 0.6874 - val_loss: 0.8202 - val_accuracy: 0.7021 - 32s/epoch - 246ms/step
# Epoch 4/50
# 129/129 - 32s - loss: 0.2630 - accuracy: 0.6954 - val_loss: 0.7965 - val_accuracy: 0.7304 - 32s/epoch - 247ms/step
# Epoch 5/50
# 129/129 - 32s - loss: 0.2584 - accuracy: 0.7022 - val_loss: 0.7825 - val_accuracy: 0.7340 - 32s/epoch - 248ms/step
# Epoch 6/50
# 129/129 - 36s - loss: 0.2549 - accuracy: 0.7080 - val_loss: 0.8203 - val_accuracy: 0.7231 - 36s/epoch - 281ms/step
# Epoch 7/50
# 129/129 - 37s - loss: 0.2519 - accuracy: 0.7106 - val_loss: 0.8216 - val_accuracy: 0.7170 - 37s/epoch - 289ms/step
# Epoch 8/50
# 129/129 - 36s - loss: 0.2496 - accuracy: 0.7081 - val_loss: 0.7840 - val_accuracy: 0.7056 - 36s/epoch - 281ms/step
# Epoch 9/50
# 129/129 - 36s - loss: 0.2481 - accuracy: 0.7090 - val_loss: 0.7953 - val_accuracy: 0.7255 - 36s/epoch - 282ms/step
# Epoch 10/50
# 129/129 - 36s - loss: 0.2458 - accuracy: 0.7111 - val_loss: 0.7801 - val_accuracy: 0.7210 - 36s/epoch - 283ms/step
# Epoch 11/50
# 129/129 - 36s - loss: 0.2445 - accuracy: 0.7098 - val_loss: 0.8008 - val_accuracy: 0.7231 - 36s/epoch - 281ms/step
# Epoch 12/50
# 129/129 - 36s - loss: 0.2431 - accuracy: 0.7092 - val_loss: 0.7517 - val_accuracy: 0.7400 - 36s/epoch - 282ms/step
# Epoch 13/50
# 129/129 - 37s - loss: 0.2408 - accuracy: 0.7106 - val_loss: 0.7735 - val_accuracy: 0.7214 - 37s/epoch - 283ms/step
# Epoch 14/50
# 129/129 - 36s - loss: 0.2398 - accuracy: 0.7104 - val_loss: 0.7517 - val_accuracy: 0.7312 - 36s/epoch - 283ms/step
# Epoch 15/50
# 129/129 - 36s - loss: 0.2376 - accuracy: 0.7071 - val_loss: 0.7560 - val_accuracy: 0.7404 - 36s/epoch - 283ms/step
# Epoch 16/50
# 129/129 - 37s - loss: 0.2354 - accuracy: 0.7067 - val_loss: 0.7731 - val_accuracy: 0.7208 - 37s/epoch - 284ms/step
# Epoch 17/50
# 129/129 - 36s - loss: 0.2331 - accuracy: 0.7025 - val_loss: 0.7684 - val_accuracy: 0.7248 - 36s/epoch - 282ms/step
# Epoch 18/50
# 129/129 - 37s - loss: 0.2316 - accuracy: 0.7067 - val_loss: 0.7860 - val_accuracy: 0.7097 - 37s/epoch - 284ms/step
# Epoch 19/50
# 129/129 - 37s - loss: 0.2287 - accuracy: 0.7069 - val_loss: 0.7685 - val_accuracy: 0.7120 - 37s/epoch - 283ms/step
# Epoch 20/50
# 129/129 - 36s - loss: 0.2272 - accuracy: 0.7068 - val_loss: 0.8110 - val_accuracy: 0.6879 - 36s/epoch - 282ms/step
# Epoch 21/50
# 129/129 - 37s - loss: 0.2239 - accuracy: 0.7080 - val_loss: 0.7871 - val_accuracy: 0.6962 - 37s/epoch - 283ms/step
# Epoch 22/50
# 129/129 - 36s - loss: 0.2215 - accuracy: 0.7060 - val_loss: 0.7487 - val_accuracy: 0.7225 - 36s/epoch - 279ms/step
# Epoch 23/50
# 129/129 - 35s - loss: 0.2185 - accuracy: 0.7052 - val_loss: 0.7727 - val_accuracy: 0.7045 - 35s/epoch - 274ms/step
# Epoch 24/50
# 129/129 - 32s - loss: 0.2156 - accuracy: 0.7077 - val_loss: 0.7941 - val_accuracy: 0.6981 - 32s/epoch - 247ms/step
# Epoch 25/50
# 129/129 - 32s - loss: 0.2123 - accuracy: 0.7061 - val_loss: 0.7769 - val_accuracy: 0.7106 - 32s/epoch - 247ms/step
# Epoch 26/50
# 129/129 - 32s - loss: 0.2088 - accuracy: 0.7092 - val_loss: 0.7996 - val_accuracy: 0.6990 - 32s/epoch - 247ms/step
# Epoch 27/50
# 129/129 - 32s - loss: 0.2058 - accuracy: 0.7108 - val_loss: 0.7759 - val_accuracy: 0.6949 - 32s/epoch - 247ms/step
# Epoch 28/50
# 129/129 - 32s - loss: 0.2027 - accuracy: 0.7092 - val_loss: 0.8150 - val_accuracy: 0.6885 - 32s/epoch - 247ms/step
# Epoch 29/50
# 129/129 - 32s - loss: 0.2004 - accuracy: 0.7108 - val_loss: 0.7948 - val_accuracy: 0.6910 - 32s/epoch - 247ms/step
# Epoch 30/50
# 129/129 - 32s - loss: 0.1962 - accuracy: 0.7117 - val_loss: 0.8195 - val_accuracy: 0.6828 - 32s/epoch - 247ms/step
# Epoch 31/50
# 129/129 - 32s - loss: 0.1940 - accuracy: 0.7104 - val_loss: 0.7712 - val_accuracy: 0.7155 - 32s/epoch - 247ms/step
# Epoch 32/50
# 129/129 - 32s - loss: 0.1912 - accuracy: 0.7122 - val_loss: 0.8091 - val_accuracy: 0.6900 - 32s/epoch - 247ms/step
# Epoch 33/50
# 129/129 - 32s - loss: 0.1876 - accuracy: 0.7142 - val_loss: 0.8040 - val_accuracy: 0.6958 - 32s/epoch - 246ms/step
# Epoch 34/50
# 129/129 - 32s - loss: 0.1848 - accuracy: 0.7161 - val_loss: 0.8061 - val_accuracy: 0.7011 - 32s/epoch - 247ms/step
# Epoch 35/50
# 129/129 - 32s - loss: 0.1832 - accuracy: 0.7191 - val_loss: 0.8291 - val_accuracy: 0.6924 - 32s/epoch - 247ms/step
# Epoch 36/50
# 129/129 - 32s - loss: 0.1812 - accuracy: 0.7201 - val_loss: 0.8185 - val_accuracy: 0.6981 - 32s/epoch - 246ms/step
# Epoch 37/50
# 129/129 - 32s - loss: 0.1779 - accuracy: 0.7242 - val_loss: 0.8050 - val_accuracy: 0.7130 - 32s/epoch - 247ms/step
# Epoch 38/50
# 129/129 - 32s - loss: 0.1764 - accuracy: 0.7273 - val_loss: 0.8295 - val_accuracy: 0.6999 - 32s/epoch - 247ms/step
# Epoch 39/50
# 129/129 - 32s - loss: 0.1741 - accuracy: 0.7255 - val_loss: 0.8404 - val_accuracy: 0.6926 - 32s/epoch - 247ms/step
# Epoch 40/50
# 129/129 - 32s - loss: 0.1725 - accuracy: 0.7281 - val_loss: 0.8778 - val_accuracy: 0.6875 - 32s/epoch - 247ms/step
# Epoch 41/50
# 129/129 - 32s - loss: 0.1706 - accuracy: 0.7306 - val_loss: 0.8467 - val_accuracy: 0.7038 - 32s/epoch - 247ms/step
# Epoch 42/50
# 129/129 - 32s - loss: 0.1687 - accuracy: 0.7317 - val_loss: 0.8177 - val_accuracy: 0.7254 - 32s/epoch - 247ms/step
# Epoch 43/50
# 129/129 - 32s - loss: 0.1682 - accuracy: 0.7348 - val_loss: 0.8675 - val_accuracy: 0.7018 - 32s/epoch - 247ms/step
# Epoch 44/50
# 129/129 - 32s - loss: 0.1654 - accuracy: 0.7375 - val_loss: 0.8495 - val_accuracy: 0.7118 - 32s/epoch - 246ms/step
# Epoch 45/50
# 129/129 - 32s - loss: 0.1647 - accuracy: 0.7386 - val_loss: 0.8726 - val_accuracy: 0.6970 - 32s/epoch - 247ms/step
# Epoch 46/50
# 129/129 - 32s - loss: 0.1631 - accuracy: 0.7386 - val_loss: 0.8696 - val_accuracy: 0.7102 - 32s/epoch - 246ms/step
# Epoch 47/50
# 129/129 - 32s - loss: 0.1617 - accuracy: 0.7448 - val_loss: 0.8953 - val_accuracy: 0.6984 - 32s/epoch - 246ms/step
# Epoch 48/50
# 129/129 - 32s - loss: 0.1612 - accuracy: 0.7438 - val_loss: 0.8550 - val_accuracy: 0.7255 - 32s/epoch - 247ms/step
# Epoch 49/50
# 129/129 - 32s - loss: 0.1598 - accuracy: 0.7468 - val_loss: 0.9004 - val_accuracy: 0.7022 - 32s/epoch - 247ms/step
# Epoch 50/50
# 129/129 - 32s - loss: 0.1586 - accuracy: 0.7479 - val_loss: 0.9001 - val_accuracy: 0.7056 - 32s/epoch - 247ms/step

# %% [markdown]
# Test models

# %%
data_test=pd.read_csv('data/test-A/expected.tsv', names = ['ASROutput'], sep='\t')
data.head()
# Out:
#                                                                                                                                                                                                  ASROutput
# 0  [w, wywiadzie, dla, ", polski, ", jarosław, kaczyński, podkreślił, ,, że, informacje, dotyczące, radosława, sikorskiego, zagrażają, interesowi, państwa, ., ", to, naprawdę, wszystko, ,, co, mogę, ...
# 1  [dowody, prokuratury, przedstawiające, ,, że, janusz, kaczmarek, ,, były, szef, mswia, ,, kłamał, ,, wypierając, się, spotkania, z, ryszardem, krauze, 5, lipca, -, nie, osłabiły, determinacji, opo...
# 2  [w, czasie, długiego, weekendu, ,, 1, -, 3, maja, 2009, w, jadwisinie, nad, jeziorem, zegrzyńskim, stowarzyszenie, wikimedia, polska, organizuje, konferencję, poświęconą, zarówno, wikimediom, ,, m...
# 3  [drugie, zwycięstwo, w, tegorocznym, giro, d, ', italia, odniósł, danilo, di, luca, z, grupy, liquigas, ,, zmieniając, tym, samym, paolo, bettiniego, na, pozycji, lidera, ., wyścig, przebiegał, dz...
# 4  [takiego, mrozu, nie, było, w, polsce, od, dawna, ., słupki, rtęci, w, znaczącej, części, polski, spadły, nie, tylko, poniżej, 10, stopni, na, minusie, ,, ale, nawet, poniżej, 20, bądź, 30, tak, z...

# %%
import ast

data_test["ASROutput"] = data_test["ASROutput"].apply(lambda x: wordpunct_tokenize(x))
test_set = data_test["ASROutput"]
test_set = [item for sublist in test_set for item in sublist]
test_set = np.array(test_set)

# %%
TOKEN_COUNT_TEST = test_set.shape[0]
drop_indices_test = [idx for idx in range(TOKEN_COUNT_TEST) if test_set[idx] in PUNCTUATION ]
labels_test = [test_set[idx+1] if idx+1 in drop_indices_test else 'NO' for idx in range(TOKEN_COUNT_TEST)]
labels_test = np.array(labels_test)
X_test_ = np.delete(test_set, drop_indices_test)
labels_test = np.delete(labels_test, drop_indices_test)
assert (X_test_.shape[0] == len(labels_test))
y_test = le.transform(labels_test)

# %%
X_test = np.empty((X_test_.shape[0], WORD_2_VEC_SIZE), dtype = float)
for idx, token in np.ndenumerate(X_test_):
    X_test[idx] = ft.get_word_vector(token)

# %% [markdown]
# ###Test model **1**

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)
# Out:
# 1274/1274 [==============================] - 12s 9ms/step

# %%
y_preds = y_pred.argmax(axis=1)
len(le.classes_)
classes = list(le.classes_)
classes.remove(classes[5]) # this class does not exist in test dataset

# %%
print(classification_report(y_test, y_preds, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#            !       0.00      0.00      0.00        23
#            "       0.00      0.00      0.00       334
#           "-       0.00      0.00      0.00        92
#            %       0.00      0.00      0.00        33
#            '       0.00      0.00      0.00        27
#            )       0.00      0.00      0.00         1
#            ,       0.00      0.00      0.00      2440
#            .       0.80      0.09      0.16      2485
#            :       0.00      0.00      0.00       321
#            ;       0.00      0.00      0.00        10
#            ?       0.00      0.00      0.00       134
#           NO       0.86      1.00      0.92     34860
#
#     accuracy                           0.86     40760
#    macro avg       0.14      0.09      0.09     40760
# weighted avg       0.78      0.86      0.80     40760
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_preds = list(le.inverse_transform(y_preds))

# %%
vocab_punct_test = {'Token': X_test_.tolist(), 'Punctuation': labels_test, "Prediction": y_preds, "Probability scores": np.max(y_pred, axis = 1)}
df_dataset_view_test = pd.DataFrame(data=vocab_punct_test)

# %%
pd.set_option('display.max_rows', 500)
df_dataset_view_test[:5]
# Out:
#      Token Punctuation Prediction  Probability scores
# 0       co          NO         NO            0.986328
# 1   znaczy           ,         NO            0.610352
# 2       że          NO         NO            0.965820
# 3  beginki           "         NO            0.661133
# 4    padły          NO         NO            0.955078

# %%
df_dataset_view_test["match_count"] = df_dataset_view_test.groupby(['Punctuation', 'Prediction'])["Prediction"].transform("count")
df_dataset_view_test["total"] = df_dataset_view_test.groupby(['Punctuation'])["Punctuation"].transform("count")
df_dataset_view_test["match_ratio"] = round(df_dataset_view_test["match_count"] / df_dataset_view_test["total"] * 100, 2)
df_dataset_view_test[:100]
# Out:
#              Token Punctuation Prediction  Probability scores  match_count  total  match_ratio
# 0               co          NO         NO            0.986328        34816  34860        99.87
# 1           znaczy           ,         NO            0.610352         2434   2440        99.75
# 2               że          NO         NO            0.965820        34816  34860        99.87
# 3          beginki           "         NO            0.661133          332    334        99.40
# 4            padły          NO         NO            0.955078        34816  34860        99.87
# 5           ofiarą          NO         NO            0.862793        34816  34860        99.87
# 6       reformacji          NO         NO            0.709473        34816  34860        99.87
# 7               "?          NO         NO            0.752930        34816  34860        99.87
# 8        grzesie2k          NO         NO            0.745117        34816  34860        99.87
# 9             wpis          NO         NO            0.777832        34816  34860        99.87
# 10              na          NO         NO            0.994629        34816  34860        99.87
# 11          słabym          NO         NO            0.903320        34816  34860        99.87
# 12        poziomie          NO         NO            0.728027        34816  34860        99.87
# 13         bzdurna          NO         NO            0.516113        34816  34860        99.87
# 14      informacja          NO         NO            0.728516        34816  34860        99.87
# 15               o          NO         NO            0.989746        34816  34860        99.87
# 16              50          NO         NO            0.864258        34816  34860        99.87
# 17       spalonych          NO         NO            0.925293        34816  34860        99.87
# 18      waldensach           ;         NO            0.580566           10     10       100.00
# 19              po          NO         NO            0.976562        34816  34860        99.87
# 20              co          NO         NO            0.986328        34816  34860        99.87
# 21               w          NO         NO            0.987793        34816  34860        99.87
# 22    bibliografii          NO         NO            0.631836        34816  34860        99.87
# 23   pseudonaukowa          NO         NO            0.571777        34816  34860        99.87
# 24         książka          NO         NO            0.722168        34816  34860        99.87
# 25       magdaleny          NO         NO            0.803223        34816  34860        99.87
# 26          ogórek           ?         NO            0.661133          132    134        98.51
# 27        fragment          NO         NO            0.814453        34816  34860        99.87
# 28        recenzji          NO         NO            0.797852        34816  34860        99.87
# 29               z          NO         NO            0.996582        34816  34860        99.87
# 30       księgarni          NO         NO            0.773438        34816  34860        99.87
# 31         gandalf           :         NO            0.604492          319    321        99.38
# 32       magdalena          NO         NO            0.938477        34816  34860        99.87
# 33          ogórek          NO         NO            0.661133        34816  34860        99.87
# 34              do          NO         NO            0.996582        34816  34860        99.87
# 35      inkwizycji          NO         NO            0.707031        34816  34860        99.87
# 36            oraz          NO         NO            0.949219        34816  34860        99.87
# 37        kościoła          NO         NO            0.764160        34816  34860        99.87
# 38              ma          NO         NO            0.986816        34816  34860        99.87
# 39        stosunek          NO         NO            0.918945        34816  34860        99.87
# 40    jednoznaczny           ,         NO            0.693848         2434   2440        99.75
# 41          pisząc          NO         NO            0.778320        34816  34860        99.87
# 42               o          NO         NO            0.989746        34816  34860        99.87
# 43   inkwizycyjnej          NO         NO            0.647949        34816  34860        99.87
# 44         pożodze          NO         NO            0.772949        34816  34860        99.87
# 45            oraz          NO         NO            0.949219        34816  34860        99.87
# 46      występkach          NO         NO            0.640625        34816  34860        99.87
# 47       heretyków          NO         NO            0.564941        34816  34860        99.87
# 48  spreparowanych          NO         NO            0.885742        34816  34860        99.87
# 49           przez          NO         NO            0.993652        34816  34860        99.87
# 50    inkwizytorów           ,         NO            0.661621         2434   2440        99.75
# 51          którzy          NO         NO            0.996582        34816  34860        99.87
# 52           siali          NO         NO            0.817383        34816  34860        99.87
# 53    spustoszenie          NO         NO            0.679199        34816  34860        99.87
# 54            oraz          NO         NO            0.949219        34816  34860        99.87
# 55               o          NO         NO            0.989746        34816  34860        99.87
# 56             tym          NO         NO            0.861328        34816  34860        99.87
# 57             jak          NO         NO            0.966309        34816  34860        99.87
# 58              to          NO         NO            0.912109        34816  34860        99.87
# 59               w          NO         NO            0.987793        34816  34860        99.87
# 60         połowie          NO         NO            0.903320        34816  34860        99.87
# 61            xiii          NO         NO            0.687012        34816  34860        99.87
# 62               w           ?         NO            0.987793          132    134        98.51
# 63        duchowni          NO         NO            0.768555        34816  34860        99.87
# 64        skupiali          NO         NO            0.933105        34816  34860        99.87
# 65             się          NO         NO            0.933105        34816  34860        99.87
# 66              na          NO         NO            0.994629        34816  34860        99.87
# 67      obsadzaniu          NO         NO            0.881836        34816  34860        99.87
# 68       stanowisk          NO         NO            0.584961        34816  34860        99.87
# 69     kościelnych           ,         NO            0.579102         2434   2440        99.75
# 70       budowaniu          NO         NO            0.957520        34816  34860        99.87
# 71          zamętu          NO         NO            0.646973        34816  34860        99.87
# 72           przez          NO         NO            0.993652        34816  34860        99.87
# 73      interdykty           ,         NO            0.650391         2434   2440        99.75
# 74         schizmy          NO         NO            0.622559        34816  34860        99.87
# 75               i          NO         NO            0.992676        34816  34860        99.87
# 76           walki           ,         NO            0.748047         2434   2440        99.75
# 77     lekceważyli          NO         NO            0.822754        34816  34860        99.87
# 78       obowiązki          NO         NO            0.876465        34816  34860        99.87
# 79  duszpasterskie           .         NO            0.657715         2260   2485        90.95
# 80             nie          NO         NO            0.983887        34816  34860        99.87
# 81          ukrywa          NO         NO            0.890137        34816  34860        99.87
# 82             też           ,         NO            0.919434         2434   2440        99.75
# 83              że          NO         NO            0.965820        34816  34860        99.87
# 84             jej          NO         NO            0.985840        34816  34860        99.87
# 85           celem          NO         NO            0.956055        34816  34860        99.87
# 86            jest          NO         NO            0.971680        34816  34860        99.87
# 87           próba          NO         NO            0.978516        34816  34860        99.87
# 88   rehabilitacji          NO         NO            0.694336        34816  34860        99.87
# 89       heretyków           .         NO            0.564941         2260   2485        90.95
# 90           takie          NO         NO            0.903320        34816  34860        99.87
# 91   jednoznacznie          NO         NO            0.735840        34816  34860        99.87
# 92    ideologiczne          NO         NO            0.584961        34816  34860        99.87
# 93      ustawienie          NO         NO            0.814941        34816  34860        99.87
# 94    problematyki          NO         NO            0.771973        34816  34860        99.87
# 95             nie          NO         NO            0.983887        34816  34860        99.87
# 96              ma          NO         NO            0.986816        34816  34860        99.87
# 97           wiele          NO         NO            0.952637        34816  34860        99.87
# 98       wspólnego          NO         NO            0.805664        34816  34860        99.87
# 99               z          NO         NO            0.996582        34816  34860        99.87

# %%
y_pred_bi = model_bi.predict(X_test)
y_preds_bi = y_pred_bi.argmax(axis=1)
# Out:
# 1274/1274 [==============================] - 20s 16ms/step

# %%
print(classification_report(y_test, y_preds_bi, target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#            !       0.03      0.04      0.03        23
#            "       0.11      0.13      0.12       334
#           "-       0.01      0.02      0.02        92
#            %       0.22      0.06      0.10        33
#            '       0.16      0.22      0.19        27
#            )       0.00      0.00      0.00         1
#            ,       0.15      0.30      0.20      2440
#            .       0.19      0.46      0.27      2485
#            :       0.17      0.14      0.15       321
#            ;       0.00      0.00      0.00        10
#            ?       0.08      0.07      0.07       134
#           NO       0.92      0.76      0.83     34860
#
#     accuracy                           0.70     40760
#    macro avg       0.17      0.18      0.16     40760
# weighted avg       0.81      0.70      0.74     40760
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_preds_bi = list(le.inverse_transform(y_preds_bi))
vocab_punct_test_bi = {'Token': X_test_.tolist(), 'Punctuation': labels_test, "Prediction": y_preds_bi, "Probability scores": np.max(y_pred_bi, axis = 1)}
df_dataset_view_test_bi = pd.DataFrame(data=vocab_punct_test_bi)

# %%
df_dataset_view_test_bi["match_count"] = df_dataset_view_test_bi.groupby(['Punctuation', 'Prediction'])["Prediction"].transform("count")
df_dataset_view_test_bi["total"] = df_dataset_view_test_bi.groupby(['Punctuation'])["Punctuation"].transform("count")
df_dataset_view_test_bi["match_ratio"] = round(df_dataset_view_test_bi["match_count"] / df_dataset_view_test_bi["total"] * 100, 2)
df_dataset_view_test_bi[:100]
# Out:
#              Token Punctuation Prediction  Probability scores  match_count  total  match_ratio
# 0               co          NO         NO            0.707031        26468  34860        75.93
# 1           znaczy           ,         NO            0.348877          999   2440        40.94
# 2               że          NO         NO            0.749023        26468  34860        75.93
# 3          beginki           "         NO            0.452881          187    334        55.99
# 4            padły          NO         NO            0.995605        26468  34860        75.93
# 5           ofiarą          NO          "            0.559082          324  34860         0.93
# 6       reformacji          NO          ,            0.581055         3552  34860        10.19
# 7               "?          NO          "            0.627930          324  34860         0.93
# 8        grzesie2k          NO         NO            0.681152        26468  34860        75.93
# 9             wpis          NO          .            0.772949         4064  34860        11.66
# 10              na          NO         NO            0.943848        26468  34860        75.93
# 11          słabym          NO         NO            0.958496        26468  34860        75.93
# 12        poziomie          NO          ,            0.467529         3552  34860        10.19
# 13         bzdurna          NO          ,            0.390137         3552  34860        10.19
# 14      informacja          NO          ,            0.479492         3552  34860        10.19
# 15               o          NO         NO            0.875977        26468  34860        75.93
# 16              50          NO         NO            0.450928        26468  34860        75.93
# 17       spalonych          NO         NO            0.934570        26468  34860        75.93
# 18      waldensach           ;         NO            0.843262            4     10        40.00
# 19              po          NO         NO            0.792480        26468  34860        75.93
# 20              co          NO         NO            0.707031        26468  34860        75.93
# 21               w          NO         NO            0.961426        26468  34860        75.93
# 22    bibliografii          NO          !            0.293457           31  34860         0.09
# 23   pseudonaukowa          NO          .            0.885254         4064  34860        11.66
# 24         książka          NO         NO            0.723633        26468  34860        75.93
# 25       magdaleny          NO         NO            0.606445        26468  34860        75.93
# 26          ogórek           ?          .            0.500977           44    134        32.84
# 27        fragment          NO          ,            0.607910         3552  34860        10.19
# 28        recenzji          NO          ,            0.920898         3552  34860        10.19
# 29               z          NO         NO            0.939941        26468  34860        75.93
# 30       księgarni          NO         NO            0.634277        26468  34860        75.93
# 31         gandalf           :          .            0.742188           44    321        13.71
# 32       magdalena          NO         NO            0.999512        26468  34860        75.93
# 33          ogórek          NO          .            0.500977         4064  34860        11.66
# 34              do          NO         NO            0.982910        26468  34860        75.93
# 35      inkwizycji          NO         NO            0.901367        26468  34860        75.93
# 36            oraz          NO         NO            0.807617        26468  34860        75.93
# 37        kościoła          NO         NO            0.791016        26468  34860        75.93
# 38              ma          NO         NO            0.960938        26468  34860        75.93
# 39        stosunek          NO         NO            0.994629        26468  34860        75.93
# 40    jednoznaczny           ,         NO            0.877441          999   2440        40.94
# 41          pisząc          NO         NO            0.982910        26468  34860        75.93
# 42               o          NO         NO            0.875977        26468  34860        75.93
# 43   inkwizycyjnej          NO          .            0.948242         4064  34860        11.66
# 44         pożodze          NO         NO            0.652344        26468  34860        75.93
# 45            oraz          NO         NO            0.807617        26468  34860        75.93
# 46      występkach          NO          .            0.545898         4064  34860        11.66
# 47       heretyków          NO          .            0.738770         4064  34860        11.66
# 48  spreparowanych          NO         NO            0.996582        26468  34860        75.93
# 49           przez          NO         NO            0.938477        26468  34860        75.93
# 50    inkwizytorów           ,         NO            0.485107          999   2440        40.94
# 51          którzy          NO         NO            0.988281        26468  34860        75.93
# 52           siali          NO         NO            0.960449        26468  34860        75.93
# 53    spustoszenie          NO          .            0.567871         4064  34860        11.66
# 54            oraz          NO         NO            0.807617        26468  34860        75.93
# 55               o          NO         NO            0.875977        26468  34860        75.93
# 56             tym          NO         NO            0.526367        26468  34860        75.93
# 57             jak          NO         NO            0.745117        26468  34860        75.93
# 58              to          NO         NO            0.519043        26468  34860        75.93
# 59               w          NO         NO            0.961426        26468  34860        75.93
# 60         połowie          NO         NO            0.744141        26468  34860        75.93
# 61            xiii          NO          .            0.851074         4064  34860        11.66
# 62               w           ?         NO            0.961426           57    134        42.54
# 63        duchowni          NO         NO            0.955078        26468  34860        75.93
# 64        skupiali          NO         NO            0.992676        26468  34860        75.93
# 65             się          NO         NO            0.742676        26468  34860        75.93
# 66              na          NO         NO            0.943848        26468  34860        75.93
# 67      obsadzaniu          NO         NO            0.903809        26468  34860        75.93
# 68       stanowisk          NO          ,            0.770508         3552  34860        10.19
# 69     kościelnych           ,         NO            0.958984          999   2440        40.94
# 70       budowaniu          NO         NO            0.998047        26468  34860        75.93
# 71          zamętu          NO          .            0.437012         4064  34860        11.66
# 72           przez          NO         NO            0.938477        26468  34860        75.93
# 73      interdykty           ,         NO            0.632324          999   2440        40.94
# 74         schizmy          NO          .            0.893066         4064  34860        11.66
# 75               i          NO         NO            0.923340        26468  34860        75.93
# 76           walki           ,          .            0.347656          652   2440        26.72
# 77     lekceważyli          NO         NO            0.996582        26468  34860        75.93
# 78       obowiązki          NO         "-            0.593750          120  34860         0.34
# 79  duszpasterskie           .          :            0.721680            8   2485         0.32
# 80             nie          NO         NO            0.786621        26468  34860        75.93
# 81          ukrywa          NO         NO            0.562012        26468  34860        75.93
# 82             też           ,         NO            0.577148          999   2440        40.94
# 83              że          NO         NO            0.749023        26468  34860        75.93
# 84             jej          NO         NO            0.945801        26468  34860        75.93
# 85           celem          NO         NO            0.701660        26468  34860        75.93
# 86            jest          NO         NO            0.715332        26468  34860        75.93
# 87           próba          NO         NO            0.999512        26468  34860        75.93
# 88   rehabilitacji          NO          .            0.542480         4064  34860        11.66
# 89       heretyków           .          .            0.738770         1145   2485        46.08
# 90           takie          NO         NO            0.785645        26468  34860        75.93
# 91   jednoznacznie          NO         NO            0.877930        26468  34860        75.93
# 92    ideologiczne          NO          .            0.776855         4064  34860        11.66
# 93      ustawienie          NO         NO            0.864746        26468  34860        75.93
# 94    problematyki          NO         NO            0.646484        26468  34860        75.93
# 95             nie          NO         NO            0.786621        26468  34860        75.93
# 96              ma          NO         NO            0.960938        26468  34860        75.93
# 97           wiele          NO         NO            0.583008        26468  34860        75.93
# 98       wspólnego          NO         NO            0.698242        26468  34860        75.93
# 99               z          NO         NO            0.939941        26468  34860        75.93

# %%
STATISTIC_COLUMNS = ["match_count", "total", "match_ratio"]
df_dataset_view_test = df_dataset_view_test.drop(columns = STATISTIC_COLUMNS)
df_dataset_view_test_bi = df_dataset_view_test_bi.drop(columns = STATISTIC_COLUMNS)
df_compare = df_dataset_view_test.join(df_dataset_view_test_bi, lsuffix='_model_1', rsuffix='_model_2')
df_compare = df_compare.drop(columns = ['Token_model_2', 'Punctuation_model_2'])
df_compare = df_compare.rename(columns={"Token_model_1": "Token", "Punctuation_model_1": "Punctuation"})

# %%
df_compare[100:150]
# Out:
#               Token Punctuation Prediction_model_1  Probability scores_model_1 Prediction_model_2  Probability scores_model_2
# 100          prawdą          NO                 NO                    0.519043                  ,                    0.935059
# 101               o          NO                 NO                    0.989746                 NO                    0.875977
# 102           epoce           ,                 NO                    0.852051                 NO                    0.750977
# 103   obiektywizmem          NO                 NO                    0.572754                  .                    0.541504
# 104    historycznym           .                 NO                    0.642578                  ,                    0.368164
# 105               w          NO                 NO                    0.987793                 NO                    0.961426
# 106         książce          NO                 NO                    0.650391                  "                    0.927246
# 107            obok          NO                 NO                    0.929199                 NO                    0.655273
# 108       ułomności          NO                 NO                    0.541016                  ,                    0.393555
# 109  merytorycznych          NO                 NO                    0.578125                  .                    0.978516
# 110               i          NO                 NO                    0.992676                 NO                    0.923340
# 111      logicznych           ,                 NO                    0.589844                  ,                    0.506348
# 112        uderzają          NO                 NO                    0.886719                 NO                    0.987305
# 113           także          NO                 NO                    0.923828                 NO                    0.609863
# 114              te          NO                 NO                    0.987793                 NO                    0.802246
# 115        formalne           .                 NO                    0.741699                  ,                    0.624023
# 116             nie          NO                 NO                    0.983887                 NO                    0.786621
# 117              do          NO                 NO                    0.996582                 NO                    0.982910
# 118           końca          NO                 NO                    0.939941                 NO                    0.604492
# 119           można          NO                 NO                    0.990723                 NO                    0.772461
# 120             tym          NO                 NO                    0.861328                 NO                    0.526367
# 121        obciążać          NO                 NO                    0.915039                 NO                    0.951172
# 122         autorkę           ,                 NO                    0.771973                 NO                    0.611816
# 123            gdyż          NO                 NO                    0.987305                 NO                    0.923828
# 124        istnieje          NO                 NO                    0.808594                 NO                    0.678711
# 125             coś          NO                 NO                    0.942871                 NO                    0.590820
# 126         takiego          NO                 NO                    0.844727                 NO                    0.987305
# 127             jak          NO                 NO                    0.966309                 NO                    0.745117
# 128        redakcja          NO                 NO                    0.810059                 NO                    0.463623
# 129             czy          NO                 NO                    0.968750                 NO                    0.795410
# 130         korekta          NO                 NO                    0.715332                 NO                    0.919922
# 131      wydawnicza           ,                 NO                    0.755371                  ,                    0.827637
# 132         których          NO                 NO                    0.965332                 NO                    0.808594
# 133    najwyraźniej          NO                 NO                    0.903320                  ,                    0.608887
# 134             nie          NO                 NO                    0.983887                 NO                    0.786621
# 135       uczyniono           .                 NO                    0.855469                 NO                    0.871094
# 136               w          NO                 NO                    0.987793                 NO                    0.961426
# 137      przeciwnym          NO                 NO                    0.792480                 NO                    0.712891
# 138           razie          NO                 NO                    0.901367                 NO                    0.931641
# 139    opublikowany          NO                 NO                    0.887695                 NO                    0.994629
# 140           tekst           ,                 NO                    0.721191                  ,                    0.313721
# 141       zwłaszcza          NO                 NO                    0.843750                 NO                    0.987305
# 142               w          NO                 NO                    0.987793                 NO                    0.961426
# 143        warstwie          NO                 NO                    0.757812                  .                    0.584473
# 144       przypisów           ,                 NO                    0.598145                  ?                    0.399658
# 145             nie          NO                 NO                    0.983887                 NO                    0.786621
# 146   przypominałby          NO                 NO                    0.896484                 NO                    0.983887
# 147      brudnopisu           ,                 NO                    0.515625                  .                    0.612305
# 148           gdzie          NO                 NO                    0.955078                 NO                    0.790039
# 149             bez          NO                 NO                    0.992676                 NO                    0.996094
